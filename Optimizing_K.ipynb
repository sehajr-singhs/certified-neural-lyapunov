# %% [markdown]
# <a href="https://colab.research.google.com/github/Wenqi-Cui/Lyapunov-Regularized-RL/blob/main/Optimizing_K.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import scipy.io
import random
import math
import scipy.io as sio
import h5py
import numpy as np
import pickle
import matplotlib.pyplot as plt

# %%
# !pip install mat4py
# Out:
# Collecting mat4py
#   Downloading mat4py-0.6.0-py2.py3-none-any.whl.metadata (2.8 kB)
# Downloading mat4py-0.6.0-py2.py3-none-any.whl (13 kB)
# Installing collected packages: mat4py
# Successfully installed mat4py-0.6.0

# %%
# A RNN-based Reinforcement Learning Framework for Frequency Control Problem with Stability Guarantee
import collections
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
import gym
import tensorflow as tf
import os
import random
from tensorflow.keras import models, layers, optimizers
from tensorflow.keras.layers import RNN
import tensorflow.keras.backend as K
import sys
from gym import spaces
from gym.utils import seeding
import copy
from mat4py import loadmat
from tensorflow.keras import layers
from tensorflow import keras
import time
import cvxpy as cp
import pickle
from numpy import linalg as LA
from mat4py import loadmat

# os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
# os.environ["CUDA_VISIBLE_DEVICES"] = "-1"
# Out:
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.

# %% [markdown]
# # Load data for time-varying voltage

# %%
# from scipy.io import loadmat
# filepath = '/content/drive/MyDrive/Colab Notebooks/250805 data center/data/record_trajectory_LossGen.mat'

# data = loadmat(filepath)
# print(data.keys())  # Show variable names in the file

# # Access a specific variable
# record_trajectory = data['record_trajectory']
# record_trajectory = np.array(record_trajectory)
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'record_trajectory'])

# %%
# f = open("/content/drive/MyDrive/Colab Notebooks/250805 data center/data/record_trajectory_LossGen.pckl", 'wb')
# pickle.dump([record_trajectory], f)
# f.close()

f = open("/content/drive/MyDrive/Colab Notebooks/250805 data center/data/record_trajectory_LossGen.pckl", 'rb')
[record_fault_trajectory] = pickle.load(f)
f.close()

# %%
# randomly print 10 cases
plt.ion()
# fig = plt.figure(figsize=(5,4), dpi=100)

for test_idx in range(5):
    fig = plt.figure(figsize=(18,4), dpi=100)

    voltage = record_fault_trajectory[test_idx,0,:,:]
    time = 0.01*np.arange(0,np.shape(voltage)[-1])
    plt.subplot(1,3,1)
    plt.plot(time, record_fault_trajectory[test_idx,0,:,:].T)
    plt.xlabel('time(s)')
    plt.ylabel('Voltage(p.u.)')

    # freq = record_fault_trajectory[test_idx,2,:,:]
    plt.subplot(1,3,2)
    plt.plot(time, record_fault_trajectory[test_idx,1,:,:].T)
    plt.xlabel('time(s)')
    plt.ylabel('omega(Hz)')

    plt.subplot(1,3,3)
    plt.plot(time, record_fault_trajectory[test_idx,2,:,:].T)
    plt.xlabel('time(s)')
    plt.ylabel('Power(p.u.)')


    plt.tight_layout()
    plt.subplots_adjust(top=0.9)
    plt.show()
    plt.pause(0.01)
    plt.clf()

# %% [markdown]
# # Environment Setup

# %% [markdown]
# ### initialize the variables and system matrices

# %%
# Frequency Control Porblem Environment
class Voltage(gym.Env):
    def  __init__(self, Matrix_X,Matrix_R, max_action,dim_action,Penalty_action):
        self.param_gamma=1
        self.Matrix_X = Matrix_X.astype(np.float32)
        self.Matrix_R = Matrix_R.astype(np.float32)
        self.inv_Matrix_X = LA.inv(Matrix_X).astype(np.float32)
        self.lambda_max = np.max(LA.eigvals(Matrix_X))
        self.max_action = max_action.astype(np.float32)
        self.dim_action=dim_action
        self.delta_t = 1
        self.state=[]
        self.Penalty_action=Penalty_action


    def step(self, action):
        # action=K.dot(self.Multiply_V_ref-K.dot(prev_output, self.select_V),tf.linalg.diag(Vector_A))
        # integrate the state transition dynamics

        self.state=(self.state-action@(self.Matrix_X.T)).copy()
        # loss = self.param_gamma*np.sum(abs(self.V_ref.T-self.state@self.select_V))
        return self.state

    def step_varyingP(self, action, Pt):


        self.state=(self.state-action@(self.Matrix_X.T)+Pt@(self.Matrix_R.T)).copy()
        return self.state

    def set_state(self, state_input):
        self.state=state_input


    def reset(self):
        self.state = np.random.uniform(-1,1,(1,self.dim_action)).astype(np.float32)

        return self.state

# %%
# Simulation data load from IEEE 39-bus system
data = loadmat('/content/drive/MyDrive/Colab Notebooks/voltage control/TestCase33.mat')
filename='TestCase'
Matrix_R=data[filename]['R']
Matrix_R=np.asarray(Matrix_R, dtype=np.float32)

Matrix_X=data[filename]['X']
Matrix_X=np.asarray(Matrix_X, dtype=np.float32)

V_ref=data[filename]['V_ref']
V_ref=np.asarray(V_ref, dtype=np.float32)

temp=data[filename]['Q_ref']
Q_ref=np.asarray(temp, dtype=np.float32)

temp=data[filename]['P_ref']
P_ref=np.asarray(temp, dtype=np.float32)

temp=data[filename]['X']
Matrix_X=np.asarray(temp, dtype=np.float32)
Matrix_X=Matrix_X*0.1
Q_ref=Q_ref*10
P_ref=P_ref*10
Matrix_R = Matrix_R*0.1
X = Matrix_X

# %%
dim_action=np.shape(Matrix_X)[0] #dimension of action space
Penalty_action=0.1
max_action= np.array([[0.04618363, 0.04674364, 0.03820283, 0.02924964, 0.02933332,
        0.02808668, 0.02881535, 0.04165629, 0.02335836, 0.01319888,
        0.04392617, 0.03839902, 0.01095371, 0.03840252, 0.02673872,
        0.02880578, 0.04716627, 0.02909166, 0.01550123, 0.02202384,
        0.01126694, 0.02100154, 0.01310747, 0.04232934, 0.0467296 ,
        0.01062543, 0.02215125, 0.01564784, 0.01676404, 0.01368452,
        0.0293981 , 0.04056301]])*10
# np.random.uniform(low=0.01, high=0.05, size=(1,dim_action))
# V_ref=Matrix_R@P_ref+Matrix_X@Q_ref+np.ones((dim_action,1))
V_ref = np.ones((dim_action,1))
Q_ref = -(LA.inv(Matrix_X))@Matrix_R@P_ref
env = Voltage(Matrix_X,Matrix_R, max_action,dim_action,Penalty_action)

# %%
lambda_max = np.max(LA.eigvals(Matrix_X))
print(LA.eigvals(Matrix_X))
2/lambda_max
# Out:
# [3.4275191e+00 1.1865367e+00 3.8679045e-01 3.5932353e-01 2.1738757e-01
#  1.6381116e-01 1.1451307e-01 7.9195574e-02 4.9670655e-02 4.0017378e-02
#  3.8222149e-02 3.5467807e-02 2.4649292e-02 2.0972826e-02 1.9898353e-02
#  1.8713778e-02 1.7802618e-02 1.5669120e-02 1.3006557e-02 1.2439296e-02
#  1.0556605e-02 1.0098979e-02 8.4837424e-03 6.8230918e-03 6.6868677e-03
#  6.1158007e-03 5.6651193e-03 5.5383639e-03 3.4610531e-03 2.3776738e-03
#  1.8364788e-03 1.6726028e-03]
# np.float32(0.5835124)

# %% [markdown]
# # CVX

# %% [markdown]
# ## Bounds for linear coefficients

# %%
Matrix_X_inv=np.linalg.inv(Matrix_X)

# %%
# weight_bound = np.ones(dim_action)

# K_bound=cp.Variable(dim_action,nonneg =True)
# objective = cp.Maximize(cp.sum(weight_bound*cp.log(K_bound)))
# diag_K_bound = cp.diag(K_bound)
# constraints = [(diag_K_bound -2*Matrix_X_inv)<<0,diag_K_bound>>0]

# prob = cp.Problem(objective, constraints)
# result = prob.solve()
# print('status',prob.status)
# K_bound=np.array(K_bound.value)

# %%
Matrix_X_inv=np.linalg.inv(Matrix_X)
Matrix_R_inv=np.linalg.inv(Matrix_R)

# %%
ratio_q = 0.5
K_bound=cp.Variable(dim_action,nonneg =True)
objective = cp.Maximize(cp.sum(cp.log(K_bound)))
diag_K_bound = cp.diag(K_bound)
constraints = [(diag_K_bound -ratio_q*2*Matrix_X_inv)<<0,diag_K_bound>>0]

prob = cp.Problem(objective, constraints)
result = prob.solve()
print('status',prob.status)
K_bound_q=np.array(K_bound.value)

ratio_p = 1 - ratio_q
K_bound=cp.Variable(dim_action,nonneg =True)
objective = cp.Maximize(cp.sum(cp.log(K_bound)))
diag_K_bound = cp.diag(K_bound)
constraints = [(diag_K_bound -ratio_p*2*Matrix_R_inv)<<0,diag_K_bound>>0]

prob = cp.Problem(objective, constraints)
result = prob.solve()
print('status',prob.status)
K_bound_p=np.array(K_bound.value)

print('K_bound_p', K_bound_p)
print('K_bound_q', K_bound_q)
# Out:
# status optimal
# status optimal
# K_bound_p [33.13205052  2.18645592  1.13989253  0.71534797  0.35978971  0.33612829
#   0.27174666  0.2133651   0.17583967  0.17061247  0.16253843  0.13960123
#   0.13357502  0.1286682   0.12429967  0.11957259  0.11828278 15.17853965
#   2.35379281  1.92837532  1.65622679  1.67080535  1.24842126  1.09967117
#   0.33913391  0.3167263   0.25973565  0.23174487  0.21944893  0.20356251
#   0.20042063  0.19872979]
# K_bound_q [74.81522491  4.91000218  2.60226066  1.66088345  0.60329601  0.43615224
#   0.39523299  0.30786703  0.25295983  0.24936051  0.2436395   0.20503434
#   0.18887919  0.18031748  0.17412578  0.16223709  0.16037872 23.35948177
#   2.88422014  2.20828     1.77388146  3.40482427  2.23567852  1.88261545
#   0.57446335  0.54289475  0.41181229  0.35382671  0.33925188  0.30356288
#   0.29555196  0.28991024]

# %% [markdown]
# ## LQR results for comparison

# %%
from scipy import linalg

# %%
def dlqr(A,B,Q,R):
    """Solve the discrete time lqr controller.


    x[k+1] = A x[k] + B u[k]

    cost = sum x[k].T*Q*x[k] + u[k].T*R*u[k]

    cite: http://www.kostasalexis.com/lqr-control.html
    """
    #ref Bertsekas, p.151

    #first, try to solve the ricatti equation
    X_ = np.matrix(linalg.solve_discrete_are(A, B, Q, R))

    #compute the LQR gain
    K_ = -np.matrix(linalg.inv(B.T@X_@B+R)*(B.T@X_@A))

    eigVals, eigVecs = linalg.eig(A+B@K_)

    return -K_, X_, eigVals

# %%
A_m = np.eye(dim_action)
B_m = np.hstack((Matrix_X, Matrix_R))
Q = np.eye(dim_action)
R = 1*np.eye(dim_action*2)
K_, X_, eigVals = dlqr(A_m,B_m,Q,R)

# %%
np.diag(K_)
# Out:
# array([0.39351821, 0.43446884, 0.43676986, 0.34958304, 0.45749813,
#        0.34246423, 0.48148863, 0.54057536, 0.37539332, 0.29324261,
#        0.33319658, 0.55859959, 0.64321566, 0.5667808 , 0.51504098,
#        0.63699886, 0.50577436, 0.67483459, 0.617381  , 0.7009809 ,
#        0.71404423, 0.54435207, 0.58210166, 0.55915177, 0.43659543,
#        0.41358803, 0.61166319, 0.52726619, 0.4015466 , 0.62150911,
#        0.66863748, 0.7337022 ])

# %% [markdown]
# # Init Simulation

# %%
#linear droop control
def Action_linear(state,linear_coff):
    action_nonconstrain = state*linear_coff
    action=action_nonconstrain
    # env.max_action-tf.nn.relu(env.max_action-action_nonconstrain)+tf.nn.relu(-env.max_action-action_nonconstrain)
    return action
def Action_constraints(action_nonconstrain):
    action=env.max_action-K.relu(env.max_action-action_nonconstrain)+K.relu(-env.max_action-action_nonconstrain)
    return action

# %%
linear_coffp= np.random.uniform(low=1, high=1, size=(1,dim_action))*0.2
linear_coffq= np.random.uniform(low=1, high=1, size=(1,dim_action))*0.2
# linear_coffp= K_[0:dim_action].reshape((1,-1))
# linear_coffq= K_[dim_action:].reshape((1,-1))
action_units=dim_action

# %% [markdown]
# ### With V0 after fault

# %%
# Plot the trajectory to visulize the performance of control
Trajectory_Linear=[]
Q_init_ratio = 0.7
P_init_ratio = 0.7
delta_t = 1
Q = (Q_ref*np.random.uniform(1-Q_init_ratio ,1+Q_init_ratio ,(dim_action, 1))).T
P = (P_ref*np.random.uniform(1-P_init_ratio ,1+P_init_ratio ,(dim_action, 1))).T

s_concate=P@Matrix_R.T+Q@Matrix_X.T
init_state=s_concate.copy()
s=init_state.copy()
SimulationLength=20
# Record_u_Linear=[]
Record_up_Linear=[]
Record_uq_Linear=[]
Trajectory_Linear.append(s)
Record_Loss_Linear=[]
Loss_Linear=0
print('s',s)
record_v0 = np.diff(record_fault_trajectory[0,0,0,110:])
for i in range(SimulationLength):
    up=np.squeeze(Action_linear(s,linear_coffp))
    uq=np.squeeze(Action_linear(s,linear_coffq))
    next_s= s - uq@Matrix_X - up@Matrix_R + record_v0[i]
    s=next_s.copy()
    Trajectory_Linear.append(s.copy())
    Record_up_Linear.append(up.copy())
    Record_uq_Linear.append(uq.copy())

Trajectory_Linear=np.squeeze(np.asarray(Trajectory_Linear))
fig = plt.figure(figsize=(11,3), dpi=100)
TimeRecord=np.arange(1,SimulationLength+2)
TimeRecord=delta_t*TimeRecord
plt.subplot(1,3,1)
plt.plot(TimeRecord,Trajectory_Linear)
plt.xlabel('time(s)')
plt.ylabel('V (p.u.)')


TimeRecord=np.arange(1,SimulationLength+1)
TimeRecord=delta_t*TimeRecord
plt.subplot(1,3,2)
plt.plot(TimeRecord,Record_up_Linear)
plt.xlabel('time(s)')
plt.ylabel('Action P')

plt.subplot(1,3,3)
plt.plot(TimeRecord,Record_uq_Linear)
plt.xlabel('time(s)')
plt.ylabel('Action Q')
fig.tight_layout()
# Out:
# s [[-0.00044382 -0.00360927 -0.00687969 -0.0102133  -0.01780124 -0.02650022
#   -0.02875587 -0.03047137 -0.03206854 -0.03196957 -0.03184066 -0.03147231
#   -0.03162721 -0.03176612 -0.03206136 -0.03136379 -0.03109144 -0.00029625
#    0.00056129  0.00062472  0.00076338 -0.00276168 -0.00186581 -0.00222253
#   -0.01754912 -0.01714169 -0.01641499 -0.01560893 -0.01555381 -0.0160386
#   -0.01607636 -0.01603852]]

# %% [markdown]
# ### With constant

# %%
# Plot the trajectory to visulize the performance of control
Trajectory_Linear=[]
Q_init_ratio = 0.7
P_init_ratio = 0.7
delta_t = 1
Q = (Q_ref*np.random.uniform(1-Q_init_ratio ,1+Q_init_ratio ,(dim_action, 1))).T
P = (P_ref*np.random.uniform(1-P_init_ratio ,1+P_init_ratio ,(dim_action, 1))).T

s_concate=P@Matrix_R.T+Q@Matrix_X.T
init_state=s_concate.copy()
s=init_state.copy()
SimulationLength=20
# Record_u_Linear=[]
Record_up_Linear=[]
Record_uq_Linear=[]
Trajectory_Linear.append(s)
Record_Loss_Linear=[]
Loss_Linear=0
print('s',s)
record_v0 =0* np.diff(record_fault_trajectory[0,0,0,110:])
for i in range(SimulationLength):
    up=np.squeeze(Action_linear(s,linear_coffp))
    uq=np.squeeze(Action_linear(s,linear_coffq))
    next_s= s - uq@Matrix_X - up@Matrix_R + record_v0[i]
    s=next_s.copy()
    Trajectory_Linear.append(s.copy())
    Record_up_Linear.append(up.copy())
    Record_uq_Linear.append(uq.copy())

Trajectory_Linear=np.squeeze(np.asarray(Trajectory_Linear))
fig = plt.figure(figsize=(11,3), dpi=100)
TimeRecord=np.arange(1,SimulationLength+2)
TimeRecord=delta_t*TimeRecord
plt.subplot(1,3,1)
plt.plot(TimeRecord,Trajectory_Linear)
plt.xlabel('time(s)')
plt.ylabel('V (p.u.)')


TimeRecord=np.arange(1,SimulationLength+1)
TimeRecord=delta_t*TimeRecord
plt.subplot(1,3,2)
plt.plot(TimeRecord,Record_up_Linear)
plt.xlabel('time(s)')
plt.ylabel('Action P')

plt.subplot(1,3,3)
plt.plot(TimeRecord,Record_uq_Linear)
plt.xlabel('time(s)')
plt.ylabel('Action Q')
fig.tight_layout()
# Out:
# s [[ 7.03953540e-05  5.89762867e-04  1.38178133e-03  2.29488448e-03
#    2.60434651e-03  3.12706702e-03  5.24464580e-03  8.19661342e-03
#    1.08960170e-02  1.11532953e-02  1.15402367e-02  1.40659232e-02
#    1.48385401e-02  1.54888278e-02  1.63128213e-02  1.71193752e-02
#    1.74193022e-02  4.18334596e-05 -4.62402321e-04 -7.07951677e-04
#   -7.76216820e-04 -2.38384938e-04 -2.13305213e-03 -2.22017521e-03
#    2.51732379e-03  2.36944580e-03  5.15742348e-03  7.47578593e-03
#    7.76844926e-03  7.45319707e-03  7.49093737e-03  7.55906230e-03]]

# %% [markdown]
# # Training

# %%
class RNNModel(tf.keras.Model):
    def __init__(self, cell):
        super().__init__()
        self.rnn = tf.keras.layers.RNN(cell, return_sequences=True, stateful=True)

    def call(self, inputs, initial_state=None):
        return self.rnn(inputs, initial_state=initial_state)

# %%
# RNN Cell to integrate state transition dynamics
class MinimalRNNCellLinear0(keras.layers.Layer):

    def __init__(self, units,action_units,internal_units,env,batchsize,K_boundq, K_boundp,**kwargs):
        self.units = units
        self.action_units = action_units
        self.state_size = units
        self.internal_units = internal_units
        self.batchsize=batchsize
        self.Matrix_X=tf.constant(env.Matrix_X,dtype=tf.float32)
        self.Matrix_R=tf.constant(env.Matrix_R,dtype=tf.float32)
        self.inv_Matrix_X = tf.constant(env.inv_Matrix_X,dtype=tf.float32)
        self.lambda_max = tf.constant(env.lambda_max,dtype=tf.float32)
        self.max_action=tf.constant(env.max_action,dtype=tf.float32)
        self.bound_slopq = tf.constant(K_boundq.reshape((1,-1)),dtype=tf.float32)
        self.bound_slopp = tf.constant(K_boundp.reshape((1,-1)),dtype=tf.float32)
        self.norm_q=1
        super(MinimalRNNCellLinear0, self).__init__(**kwargs)

    def build(self, input_shape):
        self.linear_Kp= self.add_weight(
            shape=(1,self.action_units),
            initializer=tf.keras.initializers.RandomUniform(minval=0.1, maxval=0.5),
            trainable=True,
            constraint=tf.keras.constraints.NonNeg(),
            name='linear_Kp')

        self.linear_Kq= self.add_weight(
            shape=(1,self.action_units),
            initializer=tf.keras.initializers.RandomUniform(minval=0.1, maxval=0.5),
            trainable=True,
            constraint=tf.keras.constraints.NonNeg(),
            name='linear_Kq')
        self.built = True

    def call(self, inputs_concate, states):
        # stacked ReLU structure to represent control network
        prev_state = states[0]
        prev_state_x = prev_state[:,0:self.action_units]
        prev_state_q =  prev_state[:,self.action_units:2*self.action_units]
        prev_state_p =  prev_state[:,2*self.action_units:3*self.action_units]
        inputs_p = inputs_concate[:,0:self.action_units]
        inputs_v0 = inputs_concate[:,self.action_units:self.action_units+1]


        linear_Kq_=tf.math.minimum(self.linear_Kq, self.bound_slopq )
        linear_Kp_=tf.math.minimum(self.linear_Kp, self.bound_slopp )
        action_q= K.sum(tf.linalg.diag(prev_state_x)*linear_Kq_,axis=2)
        action_p= K.sum(tf.linalg.diag(prev_state_x)*linear_Kp_,axis=2)
        # action=self.max_action-K.relu(self.max_action-action_nonconstrain)+K.relu(-self.max_action-action_nonconstrain)
        new_state_x=prev_state_x-K.dot(action_q, tf.transpose(self.Matrix_X))-K.dot(action_p, tf.transpose(self.Matrix_R))+ K.dot(inputs_p, tf.transpose(self.Matrix_R)) + K.dot(inputs_v0, tf.ones((1,self.action_units)))
        new_state_q = prev_state_q - action_q
        new_state_p = prev_state_p - action_p

        next_state =  tf.concat([new_state_x, new_state_q, new_state_p], axis = 1)


        return [new_state_x,action_q, action_p, new_state_q, new_state_p], [next_state]

# %%
# Gen_idx_Pnode = []
# for i in range(dim_action):
#     row_idx = np.random.randint(0, 13)
#     Gen_idx_Pnode.append(row_idx)

# Gen_idx_Pnode = np.asarray(Gen_idx_Pnode, dtype=np.uint32)

## Mapping time-varying load to different buses

f = open('/content/drive/MyDrive/Colab Notebooks/6. Adaptive Control/Caltech/voltage/data/Gen_idx_Pnode13.pkl', 'rb')
Gen_idx_Pnode= pickle.load(f)
f.close()

# %%
# This is the data for time-varying load
f = open('/content/drive/MyDrive/Colab Notebooks/6. Adaptive Control/Caltech/voltage/data/Caltech_data/record_pred1228n14.pckl', 'rb')

[list_true_test, list_result_test, list_norm_RegD]= pickle.load(f)
f.close()

# %%
magnitute_ratio = 0.3
list_true_test = magnitute_ratio * np.asarray(list_true_test,dtype=np.float32)
list_result_test = magnitute_ratio *np.asarray(list_result_test,dtype=np.float32)
list_true_test[3:6,:]=list_true_test[3:6,:]/10
list_result_test[3:6,:]=list_result_test[3:6,:]/10

# %%
episodes =1000 # total number of iterations to update weights
action_units=dim_action
units=action_units*3 #dimension of each state
internal_units=20 # demension of the neural network for control policy

T=100  #Total period considered
Batch_num=500 # number of batch in each episodes
learning_rate_initial=0.01
decay_stage = 100
decay_rate = 0.9

cellLinear0 = MinimalRNNCellLinear0(units,action_units,internal_units,env,Batch_num,K_bound_q,K_bound_p)
modelLinear0 = RNNModel(cellLinear0)

Loss_record=[]
Pe_rnn_record=[]
global_step = tf.Variable(0, trainable=False)
decayed_lr =tf.keras.optimizers.schedules.ExponentialDecay(
    learning_rate_initial, decay_stage, decay_rate, staircase=True)
optimizer=tf.keras.optimizers.Adam(learning_rate=decayed_lr)

Length_pred_dataset = np.array(list_true_test).shape[1]-100
column1_idx = np.arange(0,dim_action)
PrintUpdate = 1
for i in range(0,episodes):
    initial_state_q = (1- np.random.uniform(-Q_init_ratio,Q_init_ratio,(Batch_num,action_units)))*(Q_ref.T)
    initial_state_p = (1- np.random.uniform(-P_init_ratio,P_init_ratio,(Batch_num,action_units)))*(P_ref.T)
    initial_state=initial_state_p@Matrix_R.T+initial_state_q@Matrix_X.T

    Input_config = np.zeros((Batch_num,T,dim_action+1))
    for j in range(Batch_num):
       #### time varying p
       t_init_Pm = np.random.randint(0, Length_pred_dataset-T-1)
       Input_config[j,:,:dim_action]=np.transpose(list_true_test[Gen_idx_Pnode,t_init_Pm:t_init_Pm+T])
       ###### v0
       rand_fault_idx = np.random.randint(0,np.shape(record_fault_trajectory)[0])
       rand_time_idx = np.random.randint(100,150)
       rand_bus_idx = np.random.randint(0,np.shape(record_fault_trajectory)[2])
       Input_config[j,:,dim_action] = record_fault_trajectory[rand_fault_idx,0,rand_bus_idx,rand_time_idx:rand_time_idx+T]


    with tf.GradientTape(persistent=True) as tape:
        [voltage,action_q,action_p, record_q, record_p]=modelLinear0(Input_config, np.hstack((initial_state, initial_state_q, initial_state_p)))
        loss_voltage=K.sum(K.sum(K.abs(voltage)))/Batch_num/T/dim_action
        loss_action=0.01*(env.Penalty_action*K.sum(abs(record_q)))/Batch_num/T/dim_action + 0.01*(env.Penalty_action*K.sum(abs(record_p)))/Batch_num/T/dim_action
        loss=loss_voltage+loss_action
    grads = tape.gradient(loss, modelLinear0.variables)
    optimizer.apply_gradients(zip(grads, modelLinear0.variables))
    Loss_record.append(loss)



    if i % (PrintUpdate) == 0:
        print('episode',i, 'Loss',loss)
        print('         Loss_Voltage',loss_voltage, '  loss_action', loss_action)
# Out:
# episode 0 Loss tf.Tensor(3.4298282, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(3.3484762, shape=(), dtype=float32)   loss_action tf.Tensor(0.081351936, shape=(), dtype=float32)
# episode 1 Loss tf.Tensor(3.3885493, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(3.305728, shape=(), dtype=float32)   loss_action tf.Tensor(0.08282137, shape=(), dtype=float32)
# episode 2 Loss tf.Tensor(3.3412805, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(3.2571018, shape=(), dtype=float32)   loss_action tf.Tensor(0.08417867, shape=(), dtype=float32)
# episode 3 Loss tf.Tensor(3.2697322, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(3.1850863, shape=(), dtype=float32)   loss_action tf.Tensor(0.08464597, shape=(), dtype=float32)
# episode 4 Loss tf.Tensor(3.229125, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(3.143126, shape=(), dtype=float32)   loss_action tf.Tensor(0.08599894, shape=(), dtype=float32)
# episode 5 Loss tf.Tensor(3.1692004, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(3.0824494, shape=(), dtype=float32)   loss_action tf.Tensor(0.086750954, shape=(), dtype=float32)
# episode 6 Loss tf.Tensor(3.1287448, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(3.0409458, shape=(), dtype=float32)   loss_action tf.Tensor(0.08779898, shape=(), dtype=float32)
# episode 7 Loss tf.Tensor(3.0966644, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(3.0076132, shape=(), dtype=float32)   loss_action tf.Tensor(0.08905125, shape=(), dtype=float32)
# episode 8 Loss tf.Tensor(3.0660908, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.9756439, shape=(), dtype=float32)   loss_action tf.Tensor(0.09044701, shape=(), dtype=float32)
# episode 9 Loss tf.Tensor(3.0115857, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.9207969, shape=(), dtype=float32)   loss_action tf.Tensor(0.090788856, shape=(), dtype=float32)
# episode 10 Loss tf.Tensor(2.969313, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.8775806, shape=(), dtype=float32)   loss_action tf.Tensor(0.091732234, shape=(), dtype=float32)
# episode 11 Loss tf.Tensor(2.9295554, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.8368976, shape=(), dtype=float32)   loss_action tf.Tensor(0.092657804, shape=(), dtype=float32)
# episode 12 Loss tf.Tensor(2.893583, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.8001604, shape=(), dtype=float32)   loss_action tf.Tensor(0.09342261, shape=(), dtype=float32)
# episode 13 Loss tf.Tensor(2.8741875, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.779428, shape=(), dtype=float32)   loss_action tf.Tensor(0.0947594, shape=(), dtype=float32)
# episode 14 Loss tf.Tensor(2.8432777, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.7477012, shape=(), dtype=float32)   loss_action tf.Tensor(0.09557657, shape=(), dtype=float32)
# episode 15 Loss tf.Tensor(2.8266792, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.7297926, shape=(), dtype=float32)   loss_action tf.Tensor(0.09688664, shape=(), dtype=float32)
# episode 16 Loss tf.Tensor(2.7905076, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.6929557, shape=(), dtype=float32)   loss_action tf.Tensor(0.097551905, shape=(), dtype=float32)
# episode 17 Loss tf.Tensor(2.7810779, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.6819613, shape=(), dtype=float32)   loss_action tf.Tensor(0.09911659, shape=(), dtype=float32)
# episode 18 Loss tf.Tensor(2.7175767, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.6189544, shape=(), dtype=float32)   loss_action tf.Tensor(0.09862224, shape=(), dtype=float32)
# episode 19 Loss tf.Tensor(2.7193975, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.6188412, shape=(), dtype=float32)   loss_action tf.Tensor(0.10055648, shape=(), dtype=float32)
# episode 20 Loss tf.Tensor(2.682084, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.5813003, shape=(), dtype=float32)   loss_action tf.Tensor(0.1007839, shape=(), dtype=float32)
# episode 21 Loss tf.Tensor(2.6669018, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.564938, shape=(), dtype=float32)   loss_action tf.Tensor(0.1019638, shape=(), dtype=float32)
# episode 22 Loss tf.Tensor(2.638285, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.535696, shape=(), dtype=float32)   loss_action tf.Tensor(0.10258881, shape=(), dtype=float32)
# episode 23 Loss tf.Tensor(2.633373, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.5292785, shape=(), dtype=float32)   loss_action tf.Tensor(0.10409441, shape=(), dtype=float32)
# episode 24 Loss tf.Tensor(2.587066, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.4832387, shape=(), dtype=float32)   loss_action tf.Tensor(0.10382724, shape=(), dtype=float32)
# episode 25 Loss tf.Tensor(2.5638885, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.4593532, shape=(), dtype=float32)   loss_action tf.Tensor(0.10453543, shape=(), dtype=float32)
# episode 26 Loss tf.Tensor(2.5643787, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.458239, shape=(), dtype=float32)   loss_action tf.Tensor(0.10613957, shape=(), dtype=float32)
# episode 27 Loss tf.Tensor(2.5146034, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.4090858, shape=(), dtype=float32)   loss_action tf.Tensor(0.105517656, shape=(), dtype=float32)
# episode 28 Loss tf.Tensor(2.5184972, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.4113066, shape=(), dtype=float32)   loss_action tf.Tensor(0.10719052, shape=(), dtype=float32)
# episode 29 Loss tf.Tensor(2.5022674, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.3942094, shape=(), dtype=float32)   loss_action tf.Tensor(0.10805796, shape=(), dtype=float32)
# episode 30 Loss tf.Tensor(2.5093007, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.3994973, shape=(), dtype=float32)   loss_action tf.Tensor(0.10980344, shape=(), dtype=float32)
# episode 31 Loss tf.Tensor(2.4846687, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.374415, shape=(), dtype=float32)   loss_action tf.Tensor(0.110253766, shape=(), dtype=float32)
# episode 32 Loss tf.Tensor(2.4412122, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.33145, shape=(), dtype=float32)   loss_action tf.Tensor(0.109762296, shape=(), dtype=float32)
# episode 33 Loss tf.Tensor(2.4445221, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.333121, shape=(), dtype=float32)   loss_action tf.Tensor(0.1114011, shape=(), dtype=float32)
# episode 34 Loss tf.Tensor(2.4247708, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.312873, shape=(), dtype=float32)   loss_action tf.Tensor(0.11189788, shape=(), dtype=float32)
# episode 35 Loss tf.Tensor(2.4004533, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.2883422, shape=(), dtype=float32)   loss_action tf.Tensor(0.112111144, shape=(), dtype=float32)
# episode 36 Loss tf.Tensor(2.391046, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.277939, shape=(), dtype=float32)   loss_action tf.Tensor(0.11310707, shape=(), dtype=float32)
# episode 37 Loss tf.Tensor(2.35843, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.2457016, shape=(), dtype=float32)   loss_action tf.Tensor(0.1127283, shape=(), dtype=float32)
# episode 38 Loss tf.Tensor(2.3462043, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.232703, shape=(), dtype=float32)   loss_action tf.Tensor(0.11350137, shape=(), dtype=float32)
# episode 39 Loss tf.Tensor(2.3477829, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.2328374, shape=(), dtype=float32)   loss_action tf.Tensor(0.1149454, shape=(), dtype=float32)
# episode 40 Loss tf.Tensor(2.327932, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.2127078, shape=(), dtype=float32)   loss_action tf.Tensor(0.11522406, shape=(), dtype=float32)
# episode 41 Loss tf.Tensor(2.3247845, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.208518, shape=(), dtype=float32)   loss_action tf.Tensor(0.11626649, shape=(), dtype=float32)
# episode 42 Loss tf.Tensor(2.307959, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.1912088, shape=(), dtype=float32)   loss_action tf.Tensor(0.116750345, shape=(), dtype=float32)
# episode 43 Loss tf.Tensor(2.2820652, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.1653526, shape=(), dtype=float32)   loss_action tf.Tensor(0.11671247, shape=(), dtype=float32)
# episode 44 Loss tf.Tensor(2.2990758, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.1804507, shape=(), dtype=float32)   loss_action tf.Tensor(0.118625075, shape=(), dtype=float32)
# episode 45 Loss tf.Tensor(2.2779288, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.1591094, shape=(), dtype=float32)   loss_action tf.Tensor(0.118819594, shape=(), dtype=float32)
# episode 46 Loss tf.Tensor(2.2494736, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.1309428, shape=(), dtype=float32)   loss_action tf.Tensor(0.118530735, shape=(), dtype=float32)
# episode 47 Loss tf.Tensor(2.2545648, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.1346962, shape=(), dtype=float32)   loss_action tf.Tensor(0.11986849, shape=(), dtype=float32)
# episode 48 Loss tf.Tensor(2.2481854, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.1273162, shape=(), dtype=float32)   loss_action tf.Tensor(0.12086916, shape=(), dtype=float32)
# episode 49 Loss tf.Tensor(2.2281792, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.107422, shape=(), dtype=float32)   loss_action tf.Tensor(0.12075715, shape=(), dtype=float32)
# episode 50 Loss tf.Tensor(2.2131314, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.0918992, shape=(), dtype=float32)   loss_action tf.Tensor(0.121232264, shape=(), dtype=float32)
# episode 51 Loss tf.Tensor(2.19509, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.0737617, shape=(), dtype=float32)   loss_action tf.Tensor(0.12132828, shape=(), dtype=float32)
# episode 52 Loss tf.Tensor(2.189718, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.0675623, shape=(), dtype=float32)   loss_action tf.Tensor(0.12215562, shape=(), dtype=float32)
# episode 53 Loss tf.Tensor(2.18244, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.0595968, shape=(), dtype=float32)   loss_action tf.Tensor(0.12284338, shape=(), dtype=float32)
# episode 54 Loss tf.Tensor(2.1822147, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.058294, shape=(), dtype=float32)   loss_action tf.Tensor(0.123920634, shape=(), dtype=float32)
# episode 55 Loss tf.Tensor(2.1720295, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.0475376, shape=(), dtype=float32)   loss_action tf.Tensor(0.12449191, shape=(), dtype=float32)
# episode 56 Loss tf.Tensor(2.1476734, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.0236526, shape=(), dtype=float32)   loss_action tf.Tensor(0.124020785, shape=(), dtype=float32)
# episode 57 Loss tf.Tensor(2.1373088, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.0128546, shape=(), dtype=float32)   loss_action tf.Tensor(0.12445424, shape=(), dtype=float32)
# episode 58 Loss tf.Tensor(2.1218657, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.9973385, shape=(), dtype=float32)   loss_action tf.Tensor(0.124527276, shape=(), dtype=float32)
# episode 59 Loss tf.Tensor(2.1306493, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.004516, shape=(), dtype=float32)   loss_action tf.Tensor(0.12613346, shape=(), dtype=float32)
# episode 60 Loss tf.Tensor(2.129078, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(2.0019572, shape=(), dtype=float32)   loss_action tf.Tensor(0.12712064, shape=(), dtype=float32)
# episode 61 Loss tf.Tensor(2.1106203, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.9835343, shape=(), dtype=float32)   loss_action tf.Tensor(0.12708586, shape=(), dtype=float32)
# episode 62 Loss tf.Tensor(2.0871787, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.9607253, shape=(), dtype=float32)   loss_action tf.Tensor(0.12645343, shape=(), dtype=float32)
# episode 63 Loss tf.Tensor(2.1041398, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.9754382, shape=(), dtype=float32)   loss_action tf.Tensor(0.12870154, shape=(), dtype=float32)
# episode 64 Loss tf.Tensor(2.0795746, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.9514861, shape=(), dtype=float32)   loss_action tf.Tensor(0.12808846, shape=(), dtype=float32)
# episode 65 Loss tf.Tensor(2.0858128, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.9562229, shape=(), dtype=float32)   loss_action tf.Tensor(0.12958983, shape=(), dtype=float32)
# episode 66 Loss tf.Tensor(2.069163, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.9397233, shape=(), dtype=float32)   loss_action tf.Tensor(0.12943994, shape=(), dtype=float32)
# episode 67 Loss tf.Tensor(2.0583107, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.9286356, shape=(), dtype=float32)   loss_action tf.Tensor(0.12967524, shape=(), dtype=float32)
# episode 68 Loss tf.Tensor(2.0480845, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.9182075, shape=(), dtype=float32)   loss_action tf.Tensor(0.12987688, shape=(), dtype=float32)
# episode 69 Loss tf.Tensor(2.0466208, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.9156961, shape=(), dtype=float32)   loss_action tf.Tensor(0.1309247, shape=(), dtype=float32)
# episode 70 Loss tf.Tensor(2.0420446, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.910698, shape=(), dtype=float32)   loss_action tf.Tensor(0.13134661, shape=(), dtype=float32)
# episode 71 Loss tf.Tensor(2.025918, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.8945369, shape=(), dtype=float32)   loss_action tf.Tensor(0.13138118, shape=(), dtype=float32)
# episode 72 Loss tf.Tensor(2.0296886, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.8971096, shape=(), dtype=float32)   loss_action tf.Tensor(0.13257897, shape=(), dtype=float32)
# episode 73 Loss tf.Tensor(2.0238352, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.8907661, shape=(), dtype=float32)   loss_action tf.Tensor(0.13306908, shape=(), dtype=float32)
# episode 74 Loss tf.Tensor(2.0147152, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.8813522, shape=(), dtype=float32)   loss_action tf.Tensor(0.13336313, shape=(), dtype=float32)
# episode 75 Loss tf.Tensor(1.9931921, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.8603051, shape=(), dtype=float32)   loss_action tf.Tensor(0.13288702, shape=(), dtype=float32)
# episode 76 Loss tf.Tensor(1.9937559, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.8600073, shape=(), dtype=float32)   loss_action tf.Tensor(0.13374868, shape=(), dtype=float32)
# episode 77 Loss tf.Tensor(1.9699115, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.8368374, shape=(), dtype=float32)   loss_action tf.Tensor(0.13307406, shape=(), dtype=float32)
# episode 78 Loss tf.Tensor(1.9887879, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.8535814, shape=(), dtype=float32)   loss_action tf.Tensor(0.13520652, shape=(), dtype=float32)
# episode 79 Loss tf.Tensor(1.9740251, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.8389837, shape=(), dtype=float32)   loss_action tf.Tensor(0.13504148, shape=(), dtype=float32)
# episode 80 Loss tf.Tensor(1.978274, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.8418219, shape=(), dtype=float32)   loss_action tf.Tensor(0.13645212, shape=(), dtype=float32)
# episode 81 Loss tf.Tensor(1.9577827, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.8219882, shape=(), dtype=float32)   loss_action tf.Tensor(0.13579449, shape=(), dtype=float32)
# episode 82 Loss tf.Tensor(1.9584666, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.8217969, shape=(), dtype=float32)   loss_action tf.Tensor(0.13666971, shape=(), dtype=float32)
# episode 83 Loss tf.Tensor(1.9552794, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.818035, shape=(), dtype=float32)   loss_action tf.Tensor(0.13724434, shape=(), dtype=float32)
# episode 84 Loss tf.Tensor(1.9434971, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.8061225, shape=(), dtype=float32)   loss_action tf.Tensor(0.13737455, shape=(), dtype=float32)
# episode 85 Loss tf.Tensor(1.9305878, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.7933987, shape=(), dtype=float32)   loss_action tf.Tensor(0.13718909, shape=(), dtype=float32)
# episode 86 Loss tf.Tensor(1.9393085, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.8005638, shape=(), dtype=float32)   loss_action tf.Tensor(0.13874474, shape=(), dtype=float32)
# episode 87 Loss tf.Tensor(1.9385533, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.7991656, shape=(), dtype=float32)   loss_action tf.Tensor(0.13938779, shape=(), dtype=float32)
# episode 88 Loss tf.Tensor(1.9263139, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.7869853, shape=(), dtype=float32)   loss_action tf.Tensor(0.13932854, shape=(), dtype=float32)
# episode 89 Loss tf.Tensor(1.9058839, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.7672118, shape=(), dtype=float32)   loss_action tf.Tensor(0.13867208, shape=(), dtype=float32)
# episode 90 Loss tf.Tensor(1.8986088, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.759685, shape=(), dtype=float32)   loss_action tf.Tensor(0.13892372, shape=(), dtype=float32)
# episode 91 Loss tf.Tensor(1.9105366, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.7697603, shape=(), dtype=float32)   loss_action tf.Tensor(0.14077643, shape=(), dtype=float32)
# episode 92 Loss tf.Tensor(1.9020339, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.7610654, shape=(), dtype=float32)   loss_action tf.Tensor(0.14096859, shape=(), dtype=float32)
# episode 93 Loss tf.Tensor(1.898303, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.7568831, shape=(), dtype=float32)   loss_action tf.Tensor(0.14141989, shape=(), dtype=float32)
# episode 94 Loss tf.Tensor(1.8822641, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.7414447, shape=(), dtype=float32)   loss_action tf.Tensor(0.14081946, shape=(), dtype=float32)
# episode 95 Loss tf.Tensor(1.8832861, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.7414285, shape=(), dtype=float32)   loss_action tf.Tensor(0.14185765, shape=(), dtype=float32)
# episode 96 Loss tf.Tensor(1.8709232, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.7292519, shape=(), dtype=float32)   loss_action tf.Tensor(0.14167126, shape=(), dtype=float32)
# episode 97 Loss tf.Tensor(1.8705518, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.7282332, shape=(), dtype=float32)   loss_action tf.Tensor(0.14231856, shape=(), dtype=float32)
# episode 98 Loss tf.Tensor(1.8455627, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.7045125, shape=(), dtype=float32)   loss_action tf.Tensor(0.14105017, shape=(), dtype=float32)
# episode 99 Loss tf.Tensor(1.86459, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.7210002, shape=(), dtype=float32)   loss_action tf.Tensor(0.14358988, shape=(), dtype=float32)
# episode 100 Loss tf.Tensor(1.8455082, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.7027076, shape=(), dtype=float32)   loss_action tf.Tensor(0.14280054, shape=(), dtype=float32)
# episode 101 Loss tf.Tensor(1.8476596, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.7039695, shape=(), dtype=float32)   loss_action tf.Tensor(0.14369011, shape=(), dtype=float32)
# episode 102 Loss tf.Tensor(1.8427567, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.698835, shape=(), dtype=float32)   loss_action tf.Tensor(0.14392167, shape=(), dtype=float32)
# episode 103 Loss tf.Tensor(1.8278592, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.6845293, shape=(), dtype=float32)   loss_action tf.Tensor(0.14332986, shape=(), dtype=float32)
# episode 104 Loss tf.Tensor(1.8287783, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.6847993, shape=(), dtype=float32)   loss_action tf.Tensor(0.1439789, shape=(), dtype=float32)
# episode 105 Loss tf.Tensor(1.8256305, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.6811076, shape=(), dtype=float32)   loss_action tf.Tensor(0.1445229, shape=(), dtype=float32)
# episode 106 Loss tf.Tensor(1.8198012, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.6750922, shape=(), dtype=float32)   loss_action tf.Tensor(0.14470902, shape=(), dtype=float32)
# episode 107 Loss tf.Tensor(1.8136718, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.6687258, shape=(), dtype=float32)   loss_action tf.Tensor(0.14494598, shape=(), dtype=float32)
# episode 108 Loss tf.Tensor(1.8201467, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.6740459, shape=(), dtype=float32)   loss_action tf.Tensor(0.14610076, shape=(), dtype=float32)
# episode 109 Loss tf.Tensor(1.8135782, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.667452, shape=(), dtype=float32)   loss_action tf.Tensor(0.14612623, shape=(), dtype=float32)
# episode 110 Loss tf.Tensor(1.8152604, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.6682187, shape=(), dtype=float32)   loss_action tf.Tensor(0.1470417, shape=(), dtype=float32)
# episode 111 Loss tf.Tensor(1.7998936, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.6535491, shape=(), dtype=float32)   loss_action tf.Tensor(0.14634454, shape=(), dtype=float32)
# episode 112 Loss tf.Tensor(1.8006294, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.653398, shape=(), dtype=float32)   loss_action tf.Tensor(0.1472314, shape=(), dtype=float32)
# episode 113 Loss tf.Tensor(1.8103739, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.6618392, shape=(), dtype=float32)   loss_action tf.Tensor(0.14853469, shape=(), dtype=float32)
# episode 114 Loss tf.Tensor(1.7899603, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.642535, shape=(), dtype=float32)   loss_action tf.Tensor(0.14742526, shape=(), dtype=float32)
# episode 115 Loss tf.Tensor(1.7964394, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.6478473, shape=(), dtype=float32)   loss_action tf.Tensor(0.14859217, shape=(), dtype=float32)
# episode 116 Loss tf.Tensor(1.7659775, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.6193206, shape=(), dtype=float32)   loss_action tf.Tensor(0.14665686, shape=(), dtype=float32)
# episode 117 Loss tf.Tensor(1.7742509, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.6262572, shape=(), dtype=float32)   loss_action tf.Tensor(0.14799373, shape=(), dtype=float32)
# episode 118 Loss tf.Tensor(1.7707989, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.6222435, shape=(), dtype=float32)   loss_action tf.Tensor(0.14855537, shape=(), dtype=float32)
# episode 119 Loss tf.Tensor(1.7691734, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.6203076, shape=(), dtype=float32)   loss_action tf.Tensor(0.14886582, shape=(), dtype=float32)
# episode 120 Loss tf.Tensor(1.7695764, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.6202016, shape=(), dtype=float32)   loss_action tf.Tensor(0.14937484, shape=(), dtype=float32)
# episode 121 Loss tf.Tensor(1.7653935, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.615695, shape=(), dtype=float32)   loss_action tf.Tensor(0.1496985, shape=(), dtype=float32)
# episode 122 Loss tf.Tensor(1.7547133, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.605241, shape=(), dtype=float32)   loss_action tf.Tensor(0.14947242, shape=(), dtype=float32)
# episode 123 Loss tf.Tensor(1.7397056, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.5911146, shape=(), dtype=float32)   loss_action tf.Tensor(0.14859092, shape=(), dtype=float32)
# episode 124 Loss tf.Tensor(1.7430406, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.5932932, shape=(), dtype=float32)   loss_action tf.Tensor(0.1497474, shape=(), dtype=float32)
# episode 125 Loss tf.Tensor(1.7369509, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.5871797, shape=(), dtype=float32)   loss_action tf.Tensor(0.14977115, shape=(), dtype=float32)
# episode 126 Loss tf.Tensor(1.7487959, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.5973434, shape=(), dtype=float32)   loss_action tf.Tensor(0.15145245, shape=(), dtype=float32)
# episode 127 Loss tf.Tensor(1.739425, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.5882338, shape=(), dtype=float32)   loss_action tf.Tensor(0.15119106, shape=(), dtype=float32)
# episode 128 Loss tf.Tensor(1.7368284, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.5851003, shape=(), dtype=float32)   loss_action tf.Tensor(0.15172814, shape=(), dtype=float32)
# episode 129 Loss tf.Tensor(1.7341057, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.5822976, shape=(), dtype=float32)   loss_action tf.Tensor(0.15180817, shape=(), dtype=float32)
# episode 130 Loss tf.Tensor(1.7253348, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.5735549, shape=(), dtype=float32)   loss_action tf.Tensor(0.15177985, shape=(), dtype=float32)
# episode 131 Loss tf.Tensor(1.7189682, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.567244, shape=(), dtype=float32)   loss_action tf.Tensor(0.15172407, shape=(), dtype=float32)
# episode 132 Loss tf.Tensor(1.7276273, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.5744227, shape=(), dtype=float32)   loss_action tf.Tensor(0.15320459, shape=(), dtype=float32)
# episode 133 Loss tf.Tensor(1.709017, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.5570644, shape=(), dtype=float32)   loss_action tf.Tensor(0.15195261, shape=(), dtype=float32)
# episode 134 Loss tf.Tensor(1.7135879, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.5606585, shape=(), dtype=float32)   loss_action tf.Tensor(0.15292943, shape=(), dtype=float32)
# episode 135 Loss tf.Tensor(1.713791, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.5600178, shape=(), dtype=float32)   loss_action tf.Tensor(0.1537732, shape=(), dtype=float32)
# episode 136 Loss tf.Tensor(1.6916323, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.5393828, shape=(), dtype=float32)   loss_action tf.Tensor(0.15224943, shape=(), dtype=float32)
# episode 137 Loss tf.Tensor(1.7086232, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.5542381, shape=(), dtype=float32)   loss_action tf.Tensor(0.15438509, shape=(), dtype=float32)
# episode 138 Loss tf.Tensor(1.7034769, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.5490975, shape=(), dtype=float32)   loss_action tf.Tensor(0.15437943, shape=(), dtype=float32)
# episode 139 Loss tf.Tensor(1.6977847, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.5434166, shape=(), dtype=float32)   loss_action tf.Tensor(0.1543681, shape=(), dtype=float32)
# episode 140 Loss tf.Tensor(1.6886554, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.5345497, shape=(), dtype=float32)   loss_action tf.Tensor(0.1541057, shape=(), dtype=float32)
# episode 141 Loss tf.Tensor(1.6901891, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.5352856, shape=(), dtype=float32)   loss_action tf.Tensor(0.15490359, shape=(), dtype=float32)
# episode 142 Loss tf.Tensor(1.6850195, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.5301657, shape=(), dtype=float32)   loss_action tf.Tensor(0.15485379, shape=(), dtype=float32)
# episode 143 Loss tf.Tensor(1.6863364, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.5309545, shape=(), dtype=float32)   loss_action tf.Tensor(0.15538195, shape=(), dtype=float32)
# episode 144 Loss tf.Tensor(1.6708426, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.5161854, shape=(), dtype=float32)   loss_action tf.Tensor(0.15465724, shape=(), dtype=float32)
# episode 145 Loss tf.Tensor(1.6675661, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.5126387, shape=(), dtype=float32)   loss_action tf.Tensor(0.15492737, shape=(), dtype=float32)
# episode 146 Loss tf.Tensor(1.6672525, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.5117416, shape=(), dtype=float32)   loss_action tf.Tensor(0.15551084, shape=(), dtype=float32)
# episode 147 Loss tf.Tensor(1.6722872, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.5160191, shape=(), dtype=float32)   loss_action tf.Tensor(0.15626806, shape=(), dtype=float32)
# episode 148 Loss tf.Tensor(1.6683595, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.5115869, shape=(), dtype=float32)   loss_action tf.Tensor(0.15677261, shape=(), dtype=float32)
# episode 149 Loss tf.Tensor(1.6541203, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.4980881, shape=(), dtype=float32)   loss_action tf.Tensor(0.15603217, shape=(), dtype=float32)
# episode 150 Loss tf.Tensor(1.6627299, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.5055892, shape=(), dtype=float32)   loss_action tf.Tensor(0.15714063, shape=(), dtype=float32)
# episode 151 Loss tf.Tensor(1.655298, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.4983337, shape=(), dtype=float32)   loss_action tf.Tensor(0.15696427, shape=(), dtype=float32)
# episode 152 Loss tf.Tensor(1.6461984, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.4895599, shape=(), dtype=float32)   loss_action tf.Tensor(0.15663847, shape=(), dtype=float32)
# episode 153 Loss tf.Tensor(1.6531451, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.4951912, shape=(), dtype=float32)   loss_action tf.Tensor(0.15795389, shape=(), dtype=float32)
# episode 154 Loss tf.Tensor(1.6530938, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.49468, shape=(), dtype=float32)   loss_action tf.Tensor(0.15841371, shape=(), dtype=float32)
# episode 155 Loss tf.Tensor(1.6551985, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.4959612, shape=(), dtype=float32)   loss_action tf.Tensor(0.15923727, shape=(), dtype=float32)
# episode 156 Loss tf.Tensor(1.6408367, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.4826983, shape=(), dtype=float32)   loss_action tf.Tensor(0.1581384, shape=(), dtype=float32)
# episode 157 Loss tf.Tensor(1.6262825, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.4689498, shape=(), dtype=float32)   loss_action tf.Tensor(0.15733266, shape=(), dtype=float32)
# episode 158 Loss tf.Tensor(1.6386276, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.4795063, shape=(), dtype=float32)   loss_action tf.Tensor(0.15912135, shape=(), dtype=float32)
# episode 159 Loss tf.Tensor(1.6349268, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.475679, shape=(), dtype=float32)   loss_action tf.Tensor(0.15924776, shape=(), dtype=float32)
# episode 160 Loss tf.Tensor(1.6232423, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.4648318, shape=(), dtype=float32)   loss_action tf.Tensor(0.1584104, shape=(), dtype=float32)
# episode 161 Loss tf.Tensor(1.6201286, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.4612875, shape=(), dtype=float32)   loss_action tf.Tensor(0.15884113, shape=(), dtype=float32)
# episode 162 Loss tf.Tensor(1.6248505, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.4650829, shape=(), dtype=float32)   loss_action tf.Tensor(0.15976763, shape=(), dtype=float32)
# episode 163 Loss tf.Tensor(1.610908, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.4520303, shape=(), dtype=float32)   loss_action tf.Tensor(0.15887776, shape=(), dtype=float32)
# episode 164 Loss tf.Tensor(1.6185498, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.4585387, shape=(), dtype=float32)   loss_action tf.Tensor(0.16001113, shape=(), dtype=float32)
# episode 165 Loss tf.Tensor(1.6176803, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.4571671, shape=(), dtype=float32)   loss_action tf.Tensor(0.16051319, shape=(), dtype=float32)
# episode 166 Loss tf.Tensor(1.6203539, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.4589375, shape=(), dtype=float32)   loss_action tf.Tensor(0.16141647, shape=(), dtype=float32)
# episode 167 Loss tf.Tensor(1.6104311, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.4497337, shape=(), dtype=float32)   loss_action tf.Tensor(0.16069736, shape=(), dtype=float32)
# episode 168 Loss tf.Tensor(1.6177652, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.455681, shape=(), dtype=float32)   loss_action tf.Tensor(0.16208425, shape=(), dtype=float32)
# episode 169 Loss tf.Tensor(1.5988337, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.4382442, shape=(), dtype=float32)   loss_action tf.Tensor(0.16058949, shape=(), dtype=float32)
# episode 170 Loss tf.Tensor(1.6020964, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.4407992, shape=(), dtype=float32)   loss_action tf.Tensor(0.1612972, shape=(), dtype=float32)
# episode 171 Loss tf.Tensor(1.6025867, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.4405601, shape=(), dtype=float32)   loss_action tf.Tensor(0.16202658, shape=(), dtype=float32)
# episode 172 Loss tf.Tensor(1.5893238, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.428181, shape=(), dtype=float32)   loss_action tf.Tensor(0.16114265, shape=(), dtype=float32)
# episode 173 Loss tf.Tensor(1.5891755, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.4275304, shape=(), dtype=float32)   loss_action tf.Tensor(0.1616451, shape=(), dtype=float32)
# episode 174 Loss tf.Tensor(1.588872, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.4265975, shape=(), dtype=float32)   loss_action tf.Tensor(0.16227448, shape=(), dtype=float32)
# episode 175 Loss tf.Tensor(1.5864453, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.4241405, shape=(), dtype=float32)   loss_action tf.Tensor(0.16230488, shape=(), dtype=float32)
# episode 176 Loss tf.Tensor(1.5893328, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.4261757, shape=(), dtype=float32)   loss_action tf.Tensor(0.16315705, shape=(), dtype=float32)
# episode 177 Loss tf.Tensor(1.5914599, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.4276013, shape=(), dtype=float32)   loss_action tf.Tensor(0.16385853, shape=(), dtype=float32)
# episode 178 Loss tf.Tensor(1.5788857, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.416006, shape=(), dtype=float32)   loss_action tf.Tensor(0.1628797, shape=(), dtype=float32)
# episode 179 Loss tf.Tensor(1.5866306, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.4222134, shape=(), dtype=float32)   loss_action tf.Tensor(0.16441709, shape=(), dtype=float32)
# episode 180 Loss tf.Tensor(1.5858438, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.4211062, shape=(), dtype=float32)   loss_action tf.Tensor(0.16473755, shape=(), dtype=float32)
# episode 181 Loss tf.Tensor(1.5755349, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.4113758, shape=(), dtype=float32)   loss_action tf.Tensor(0.16415921, shape=(), dtype=float32)
# episode 182 Loss tf.Tensor(1.5636708, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.4005003, shape=(), dtype=float32)   loss_action tf.Tensor(0.16317049, shape=(), dtype=float32)
# episode 183 Loss tf.Tensor(1.5597696, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.3964642, shape=(), dtype=float32)   loss_action tf.Tensor(0.16330534, shape=(), dtype=float32)
# episode 184 Loss tf.Tensor(1.5606722, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.3968571, shape=(), dtype=float32)   loss_action tf.Tensor(0.16381499, shape=(), dtype=float32)
# episode 185 Loss tf.Tensor(1.5632243, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.3985485, shape=(), dtype=float32)   loss_action tf.Tensor(0.1646758, shape=(), dtype=float32)
# episode 186 Loss tf.Tensor(1.560666, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.3957497, shape=(), dtype=float32)   loss_action tf.Tensor(0.16491628, shape=(), dtype=float32)
# episode 187 Loss tf.Tensor(1.5603274, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.394954, shape=(), dtype=float32)   loss_action tf.Tensor(0.16537349, shape=(), dtype=float32)
# episode 188 Loss tf.Tensor(1.5494971, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.3847857, shape=(), dtype=float32)   loss_action tf.Tensor(0.16471153, shape=(), dtype=float32)
# episode 189 Loss tf.Tensor(1.5454355, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.3808693, shape=(), dtype=float32)   loss_action tf.Tensor(0.16456628, shape=(), dtype=float32)
# episode 190 Loss tf.Tensor(1.5491934, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.383679, shape=(), dtype=float32)   loss_action tf.Tensor(0.16551438, shape=(), dtype=float32)
# episode 191 Loss tf.Tensor(1.555474, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.3888829, shape=(), dtype=float32)   loss_action tf.Tensor(0.1665912, shape=(), dtype=float32)
# episode 192 Loss tf.Tensor(1.5473475, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.3812637, shape=(), dtype=float32)   loss_action tf.Tensor(0.16608378, shape=(), dtype=float32)
# episode 193 Loss tf.Tensor(1.53122, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.3662682, shape=(), dtype=float32)   loss_action tf.Tensor(0.16495177, shape=(), dtype=float32)
# episode 194 Loss tf.Tensor(1.5463184, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.3794086, shape=(), dtype=float32)   loss_action tf.Tensor(0.16690984, shape=(), dtype=float32)
# episode 195 Loss tf.Tensor(1.5423634, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.3753569, shape=(), dtype=float32)   loss_action tf.Tensor(0.16700655, shape=(), dtype=float32)
# episode 196 Loss tf.Tensor(1.5391133, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.3718877, shape=(), dtype=float32)   loss_action tf.Tensor(0.16722563, shape=(), dtype=float32)
# episode 197 Loss tf.Tensor(1.5336787, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.366758, shape=(), dtype=float32)   loss_action tf.Tensor(0.16692069, shape=(), dtype=float32)
# episode 198 Loss tf.Tensor(1.5317723, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.3643872, shape=(), dtype=float32)   loss_action tf.Tensor(0.16738509, shape=(), dtype=float32)
# episode 199 Loss tf.Tensor(1.5312734, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.3637538, shape=(), dtype=float32)   loss_action tf.Tensor(0.16751957, shape=(), dtype=float32)
# episode 200 Loss tf.Tensor(1.5245719, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.3573667, shape=(), dtype=float32)   loss_action tf.Tensor(0.16720524, shape=(), dtype=float32)
# episode 201 Loss tf.Tensor(1.5277267, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.3595474, shape=(), dtype=float32)   loss_action tf.Tensor(0.16817926, shape=(), dtype=float32)
# episode 202 Loss tf.Tensor(1.5164936, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.3493013, shape=(), dtype=float32)   loss_action tf.Tensor(0.16719219, shape=(), dtype=float32)
# episode 203 Loss tf.Tensor(1.5151598, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.3478608, shape=(), dtype=float32)   loss_action tf.Tensor(0.16729897, shape=(), dtype=float32)
# episode 204 Loss tf.Tensor(1.5236479, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.3548032, shape=(), dtype=float32)   loss_action tf.Tensor(0.16884474, shape=(), dtype=float32)
# episode 205 Loss tf.Tensor(1.5201815, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.351308, shape=(), dtype=float32)   loss_action tf.Tensor(0.1688735, shape=(), dtype=float32)
# episode 206 Loss tf.Tensor(1.5168581, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.3482254, shape=(), dtype=float32)   loss_action tf.Tensor(0.1686328, shape=(), dtype=float32)
# episode 207 Loss tf.Tensor(1.5138359, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.3449597, shape=(), dtype=float32)   loss_action tf.Tensor(0.16887617, shape=(), dtype=float32)
# episode 208 Loss tf.Tensor(1.516785, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.3473477, shape=(), dtype=float32)   loss_action tf.Tensor(0.16943724, shape=(), dtype=float32)
# episode 209 Loss tf.Tensor(1.5097933, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.3406698, shape=(), dtype=float32)   loss_action tf.Tensor(0.16912347, shape=(), dtype=float32)
# episode 210 Loss tf.Tensor(1.5105872, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.3409194, shape=(), dtype=float32)   loss_action tf.Tensor(0.16966781, shape=(), dtype=float32)
# episode 211 Loss tf.Tensor(1.51515, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.3446336, shape=(), dtype=float32)   loss_action tf.Tensor(0.17051639, shape=(), dtype=float32)
# episode 212 Loss tf.Tensor(1.5087967, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.3384764, shape=(), dtype=float32)   loss_action tf.Tensor(0.17032027, shape=(), dtype=float32)
# episode 213 Loss tf.Tensor(1.5005322, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.3308166, shape=(), dtype=float32)   loss_action tf.Tensor(0.16971555, shape=(), dtype=float32)
# episode 214 Loss tf.Tensor(1.5078459, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.3369949, shape=(), dtype=float32)   loss_action tf.Tensor(0.17085105, shape=(), dtype=float32)
# episode 215 Loss tf.Tensor(1.490565, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.3214707, shape=(), dtype=float32)   loss_action tf.Tensor(0.1690942, shape=(), dtype=float32)
# episode 216 Loss tf.Tensor(1.4958248, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.325551, shape=(), dtype=float32)   loss_action tf.Tensor(0.17027384, shape=(), dtype=float32)
# episode 217 Loss tf.Tensor(1.4916316, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.3214018, shape=(), dtype=float32)   loss_action tf.Tensor(0.17022978, shape=(), dtype=float32)
# episode 218 Loss tf.Tensor(1.4973829, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.3261211, shape=(), dtype=float32)   loss_action tf.Tensor(0.17126176, shape=(), dtype=float32)
# episode 219 Loss tf.Tensor(1.4864702, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.316333, shape=(), dtype=float32)   loss_action tf.Tensor(0.17013717, shape=(), dtype=float32)
# episode 220 Loss tf.Tensor(1.4883603, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.3175044, shape=(), dtype=float32)   loss_action tf.Tensor(0.17085591, shape=(), dtype=float32)
# episode 221 Loss tf.Tensor(1.4945657, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.3225942, shape=(), dtype=float32)   loss_action tf.Tensor(0.17197156, shape=(), dtype=float32)
# episode 222 Loss tf.Tensor(1.4836192, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.3124205, shape=(), dtype=float32)   loss_action tf.Tensor(0.17119871, shape=(), dtype=float32)
# episode 223 Loss tf.Tensor(1.4886134, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.3164636, shape=(), dtype=float32)   loss_action tf.Tensor(0.17214972, shape=(), dtype=float32)
# episode 224 Loss tf.Tensor(1.4814737, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.3097705, shape=(), dtype=float32)   loss_action tf.Tensor(0.17170316, shape=(), dtype=float32)
# episode 225 Loss tf.Tensor(1.4744434, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.30348, shape=(), dtype=float32)   loss_action tf.Tensor(0.17096338, shape=(), dtype=float32)
# episode 226 Loss tf.Tensor(1.4721941, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.3010209, shape=(), dtype=float32)   loss_action tf.Tensor(0.17117321, shape=(), dtype=float32)
# episode 227 Loss tf.Tensor(1.4778694, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.3054452, shape=(), dtype=float32)   loss_action tf.Tensor(0.17242415, shape=(), dtype=float32)
# episode 228 Loss tf.Tensor(1.4810231, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.307784, shape=(), dtype=float32)   loss_action tf.Tensor(0.1732391, shape=(), dtype=float32)
# episode 229 Loss tf.Tensor(1.4714488, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.2992406, shape=(), dtype=float32)   loss_action tf.Tensor(0.17220822, shape=(), dtype=float32)
# episode 230 Loss tf.Tensor(1.4710466, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.2984997, shape=(), dtype=float32)   loss_action tf.Tensor(0.17254683, shape=(), dtype=float32)
# episode 231 Loss tf.Tensor(1.4654238, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.2933232, shape=(), dtype=float32)   loss_action tf.Tensor(0.1721006, shape=(), dtype=float32)
# episode 232 Loss tf.Tensor(1.4614763, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.2894218, shape=(), dtype=float32)   loss_action tf.Tensor(0.17205454, shape=(), dtype=float32)
# episode 233 Loss tf.Tensor(1.4627851, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.2900215, shape=(), dtype=float32)   loss_action tf.Tensor(0.17276359, shape=(), dtype=float32)
# episode 234 Loss tf.Tensor(1.4655764, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.2924496, shape=(), dtype=float32)   loss_action tf.Tensor(0.17312683, shape=(), dtype=float32)
# episode 235 Loss tf.Tensor(1.464226, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.290595, shape=(), dtype=float32)   loss_action tf.Tensor(0.17363091, shape=(), dtype=float32)
# episode 236 Loss tf.Tensor(1.4487002, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.2766199, shape=(), dtype=float32)   loss_action tf.Tensor(0.17208025, shape=(), dtype=float32)
# episode 237 Loss tf.Tensor(1.4521816, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.2792546, shape=(), dtype=float32)   loss_action tf.Tensor(0.17292705, shape=(), dtype=float32)
# episode 238 Loss tf.Tensor(1.4612018, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.2867911, shape=(), dtype=float32)   loss_action tf.Tensor(0.17441073, shape=(), dtype=float32)
# episode 239 Loss tf.Tensor(1.4593536, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.2849054, shape=(), dtype=float32)   loss_action tf.Tensor(0.1744481, shape=(), dtype=float32)
# episode 240 Loss tf.Tensor(1.4423015, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.2695433, shape=(), dtype=float32)   loss_action tf.Tensor(0.17275828, shape=(), dtype=float32)
# episode 241 Loss tf.Tensor(1.4516869, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.2774367, shape=(), dtype=float32)   loss_action tf.Tensor(0.17425013, shape=(), dtype=float32)
# episode 242 Loss tf.Tensor(1.4470695, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.2730597, shape=(), dtype=float32)   loss_action tf.Tensor(0.17400977, shape=(), dtype=float32)
# episode 243 Loss tf.Tensor(1.446578, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.2722745, shape=(), dtype=float32)   loss_action tf.Tensor(0.17430359, shape=(), dtype=float32)
# episode 244 Loss tf.Tensor(1.4335251, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.2604371, shape=(), dtype=float32)   loss_action tf.Tensor(0.1730879, shape=(), dtype=float32)
# episode 245 Loss tf.Tensor(1.4431366, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.2686557, shape=(), dtype=float32)   loss_action tf.Tensor(0.17448092, shape=(), dtype=float32)
# episode 246 Loss tf.Tensor(1.4411101, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.266557, shape=(), dtype=float32)   loss_action tf.Tensor(0.17455316, shape=(), dtype=float32)
# episode 247 Loss tf.Tensor(1.4374872, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.2628864, shape=(), dtype=float32)   loss_action tf.Tensor(0.17460082, shape=(), dtype=float32)
# episode 248 Loss tf.Tensor(1.4367496, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.2619456, shape=(), dtype=float32)   loss_action tf.Tensor(0.17480394, shape=(), dtype=float32)
# episode 249 Loss tf.Tensor(1.4377668, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.2622415, shape=(), dtype=float32)   loss_action tf.Tensor(0.17552528, shape=(), dtype=float32)
# episode 250 Loss tf.Tensor(1.4376068, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(1.2618928, shape=(), dtype=float32)   loss_action tf.Tensor(0.17571405, shape=(), dtype=float32)
# ...
# episode 917 Loss tf.Tensor(1.039141, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.8183786, shape=(), dtype=float32)   loss_action tf.Tensor(0.22076245, shape=(), dtype=float32)
# episode 918 Loss tf.Tensor(1.0380124, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.8173722, shape=(), dtype=float32)   loss_action tf.Tensor(0.22064017, shape=(), dtype=float32)
# episode 919 Loss tf.Tensor(1.0354023, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.81513095, shape=(), dtype=float32)   loss_action tf.Tensor(0.22027141, shape=(), dtype=float32)
# episode 920 Loss tf.Tensor(1.0297487, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.81097573, shape=(), dtype=float32)   loss_action tf.Tensor(0.21877289, shape=(), dtype=float32)
# episode 921 Loss tf.Tensor(1.0320616, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.8125983, shape=(), dtype=float32)   loss_action tf.Tensor(0.21946332, shape=(), dtype=float32)
# episode 922 Loss tf.Tensor(1.0387152, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.8176442, shape=(), dtype=float32)   loss_action tf.Tensor(0.22107106, shape=(), dtype=float32)
# episode 923 Loss tf.Tensor(1.0354135, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.81511, shape=(), dtype=float32)   loss_action tf.Tensor(0.2203035, shape=(), dtype=float32)
# episode 924 Loss tf.Tensor(1.0276726, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.8090572, shape=(), dtype=float32)   loss_action tf.Tensor(0.21861543, shape=(), dtype=float32)
# episode 925 Loss tf.Tensor(1.044343, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.82190454, shape=(), dtype=float32)   loss_action tf.Tensor(0.22243848, shape=(), dtype=float32)
# episode 926 Loss tf.Tensor(1.0398183, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.81827426, shape=(), dtype=float32)   loss_action tf.Tensor(0.22154403, shape=(), dtype=float32)
# episode 927 Loss tf.Tensor(1.0386701, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.8171303, shape=(), dtype=float32)   loss_action tf.Tensor(0.22153978, shape=(), dtype=float32)
# episode 928 Loss tf.Tensor(1.0344484, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.814002, shape=(), dtype=float32)   loss_action tf.Tensor(0.22044647, shape=(), dtype=float32)
# episode 929 Loss tf.Tensor(1.041457, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.81928515, shape=(), dtype=float32)   loss_action tf.Tensor(0.22217193, shape=(), dtype=float32)
# episode 930 Loss tf.Tensor(1.0407326, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.81859237, shape=(), dtype=float32)   loss_action tf.Tensor(0.22214028, shape=(), dtype=float32)
# episode 931 Loss tf.Tensor(1.0376233, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.81621516, shape=(), dtype=float32)   loss_action tf.Tensor(0.22140813, shape=(), dtype=float32)
# episode 932 Loss tf.Tensor(1.0336639, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.8130302, shape=(), dtype=float32)   loss_action tf.Tensor(0.22063372, shape=(), dtype=float32)
# episode 933 Loss tf.Tensor(1.0342761, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.81306833, shape=(), dtype=float32)   loss_action tf.Tensor(0.22120777, shape=(), dtype=float32)
# episode 934 Loss tf.Tensor(1.0321891, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.8115442, shape=(), dtype=float32)   loss_action tf.Tensor(0.22064489, shape=(), dtype=float32)
# episode 935 Loss tf.Tensor(1.0323546, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.8116107, shape=(), dtype=float32)   loss_action tf.Tensor(0.22074394, shape=(), dtype=float32)
# episode 936 Loss tf.Tensor(1.0302342, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.8100818, shape=(), dtype=float32)   loss_action tf.Tensor(0.22015241, shape=(), dtype=float32)
# episode 937 Loss tf.Tensor(1.0327684, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.8118733, shape=(), dtype=float32)   loss_action tf.Tensor(0.220895, shape=(), dtype=float32)
# episode 938 Loss tf.Tensor(1.0375197, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.81540906, shape=(), dtype=float32)   loss_action tf.Tensor(0.22211069, shape=(), dtype=float32)
# episode 939 Loss tf.Tensor(1.0400219, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.8171212, shape=(), dtype=float32)   loss_action tf.Tensor(0.22290063, shape=(), dtype=float32)
# episode 940 Loss tf.Tensor(1.0302608, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.8095351, shape=(), dtype=float32)   loss_action tf.Tensor(0.22072566, shape=(), dtype=float32)
# episode 941 Loss tf.Tensor(1.0362792, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.81402797, shape=(), dtype=float32)   loss_action tf.Tensor(0.22225124, shape=(), dtype=float32)
# episode 942 Loss tf.Tensor(1.0290475, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.8083751, shape=(), dtype=float32)   loss_action tf.Tensor(0.22067237, shape=(), dtype=float32)
# episode 943 Loss tf.Tensor(1.0344894, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.81285554, shape=(), dtype=float32)   loss_action tf.Tensor(0.22163385, shape=(), dtype=float32)
# episode 944 Loss tf.Tensor(1.0229379, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.8034603, shape=(), dtype=float32)   loss_action tf.Tensor(0.21947762, shape=(), dtype=float32)
# episode 945 Loss tf.Tensor(1.0271187, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.8069137, shape=(), dtype=float32)   loss_action tf.Tensor(0.22020498, shape=(), dtype=float32)
# episode 946 Loss tf.Tensor(1.0291426, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.808227, shape=(), dtype=float32)   loss_action tf.Tensor(0.22091566, shape=(), dtype=float32)
# episode 947 Loss tf.Tensor(1.0345067, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.812448, shape=(), dtype=float32)   loss_action tf.Tensor(0.22205862, shape=(), dtype=float32)
# episode 948 Loss tf.Tensor(1.0330868, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.8111953, shape=(), dtype=float32)   loss_action tf.Tensor(0.22189142, shape=(), dtype=float32)
# episode 949 Loss tf.Tensor(1.0290654, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.80808496, shape=(), dtype=float32)   loss_action tf.Tensor(0.22098038, shape=(), dtype=float32)
# episode 950 Loss tf.Tensor(1.0370383, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.81395674, shape=(), dtype=float32)   loss_action tf.Tensor(0.22308153, shape=(), dtype=float32)
# episode 951 Loss tf.Tensor(1.0370257, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.8140142, shape=(), dtype=float32)   loss_action tf.Tensor(0.22301143, shape=(), dtype=float32)
# episode 952 Loss tf.Tensor(1.025626, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.80506724, shape=(), dtype=float32)   loss_action tf.Tensor(0.22055875, shape=(), dtype=float32)
# episode 953 Loss tf.Tensor(1.0280346, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.8070065, shape=(), dtype=float32)   loss_action tf.Tensor(0.22102806, shape=(), dtype=float32)
# episode 954 Loss tf.Tensor(1.0281376, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.8071154, shape=(), dtype=float32)   loss_action tf.Tensor(0.22102223, shape=(), dtype=float32)
# episode 955 Loss tf.Tensor(1.0327181, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.8103723, shape=(), dtype=float32)   loss_action tf.Tensor(0.22234574, shape=(), dtype=float32)
# episode 956 Loss tf.Tensor(1.0320629, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.8097843, shape=(), dtype=float32)   loss_action tf.Tensor(0.22227862, shape=(), dtype=float32)
# episode 957 Loss tf.Tensor(1.0261766, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.8049408, shape=(), dtype=float32)   loss_action tf.Tensor(0.22123575, shape=(), dtype=float32)
# episode 958 Loss tf.Tensor(1.0277336, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.8061024, shape=(), dtype=float32)   loss_action tf.Tensor(0.22163118, shape=(), dtype=float32)
# episode 959 Loss tf.Tensor(1.0329885, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.8104101, shape=(), dtype=float32)   loss_action tf.Tensor(0.2225785, shape=(), dtype=float32)
# episode 960 Loss tf.Tensor(1.0279572, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.806287, shape=(), dtype=float32)   loss_action tf.Tensor(0.22167027, shape=(), dtype=float32)
# episode 961 Loss tf.Tensor(1.0376871, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.81358856, shape=(), dtype=float32)   loss_action tf.Tensor(0.22409844, shape=(), dtype=float32)
# episode 962 Loss tf.Tensor(1.0263672, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.80469376, shape=(), dtype=float32)   loss_action tf.Tensor(0.22167343, shape=(), dtype=float32)
# episode 963 Loss tf.Tensor(1.0330894, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.810133, shape=(), dtype=float32)   loss_action tf.Tensor(0.22295645, shape=(), dtype=float32)
# episode 964 Loss tf.Tensor(1.0285338, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.80641246, shape=(), dtype=float32)   loss_action tf.Tensor(0.22212139, shape=(), dtype=float32)
# episode 965 Loss tf.Tensor(1.0209403, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.8006729, shape=(), dtype=float32)   loss_action tf.Tensor(0.22026744, shape=(), dtype=float32)
# episode 966 Loss tf.Tensor(1.0287986, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.8065717, shape=(), dtype=float32)   loss_action tf.Tensor(0.22222683, shape=(), dtype=float32)
# episode 967 Loss tf.Tensor(1.0307883, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.80785483, shape=(), dtype=float32)   loss_action tf.Tensor(0.2229335, shape=(), dtype=float32)
# episode 968 Loss tf.Tensor(1.0195273, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.79925036, shape=(), dtype=float32)   loss_action tf.Tensor(0.22027692, shape=(), dtype=float32)
# episode 969 Loss tf.Tensor(1.0305297, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.8072528, shape=(), dtype=float32)   loss_action tf.Tensor(0.22327697, shape=(), dtype=float32)
# episode 970 Loss tf.Tensor(1.0185845, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.7982559, shape=(), dtype=float32)   loss_action tf.Tensor(0.22032857, shape=(), dtype=float32)
# episode 971 Loss tf.Tensor(1.0294626, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.8065989, shape=(), dtype=float32)   loss_action tf.Tensor(0.22286361, shape=(), dtype=float32)
# episode 972 Loss tf.Tensor(1.0276729, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.804985, shape=(), dtype=float32)   loss_action tf.Tensor(0.2226879, shape=(), dtype=float32)
# episode 973 Loss tf.Tensor(1.024126, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.802306, shape=(), dtype=float32)   loss_action tf.Tensor(0.22182012, shape=(), dtype=float32)
# episode 974 Loss tf.Tensor(1.0240413, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.80217016, shape=(), dtype=float32)   loss_action tf.Tensor(0.22187117, shape=(), dtype=float32)
# episode 975 Loss tf.Tensor(1.0235071, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.8013624, shape=(), dtype=float32)   loss_action tf.Tensor(0.22214472, shape=(), dtype=float32)
# episode 976 Loss tf.Tensor(1.0322034, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.80830175, shape=(), dtype=float32)   loss_action tf.Tensor(0.22390166, shape=(), dtype=float32)
# episode 977 Loss tf.Tensor(1.0246886, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.80246466, shape=(), dtype=float32)   loss_action tf.Tensor(0.22222394, shape=(), dtype=float32)
# episode 978 Loss tf.Tensor(1.0196302, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.79838365, shape=(), dtype=float32)   loss_action tf.Tensor(0.22124651, shape=(), dtype=float32)
# episode 979 Loss tf.Tensor(1.0239174, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.8015845, shape=(), dtype=float32)   loss_action tf.Tensor(0.2223329, shape=(), dtype=float32)
# episode 980 Loss tf.Tensor(1.0305073, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.80666375, shape=(), dtype=float32)   loss_action tf.Tensor(0.22384363, shape=(), dtype=float32)
# episode 981 Loss tf.Tensor(1.0222806, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.80006784, shape=(), dtype=float32)   loss_action tf.Tensor(0.2222127, shape=(), dtype=float32)
# episode 982 Loss tf.Tensor(1.023074, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.80079645, shape=(), dtype=float32)   loss_action tf.Tensor(0.22227758, shape=(), dtype=float32)
# episode 983 Loss tf.Tensor(1.0262985, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.80324984, shape=(), dtype=float32)   loss_action tf.Tensor(0.22304867, shape=(), dtype=float32)
# episode 984 Loss tf.Tensor(1.0283903, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.8046579, shape=(), dtype=float32)   loss_action tf.Tensor(0.22373238, shape=(), dtype=float32)
# episode 985 Loss tf.Tensor(1.0226716, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.80024546, shape=(), dtype=float32)   loss_action tf.Tensor(0.22242609, shape=(), dtype=float32)
# episode 986 Loss tf.Tensor(1.0335919, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.80833596, shape=(), dtype=float32)   loss_action tf.Tensor(0.22525588, shape=(), dtype=float32)
# episode 987 Loss tf.Tensor(1.023849, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.8011774, shape=(), dtype=float32)   loss_action tf.Tensor(0.22267157, shape=(), dtype=float32)
# episode 988 Loss tf.Tensor(1.018166, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.7963843, shape=(), dtype=float32)   loss_action tf.Tensor(0.22178164, shape=(), dtype=float32)
# episode 989 Loss tf.Tensor(1.0204333, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.79822326, shape=(), dtype=float32)   loss_action tf.Tensor(0.22221006, shape=(), dtype=float32)
# episode 990 Loss tf.Tensor(1.0217307, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.7990886, shape=(), dtype=float32)   loss_action tf.Tensor(0.22264206, shape=(), dtype=float32)
# episode 991 Loss tf.Tensor(1.0127715, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.7920606, shape=(), dtype=float32)   loss_action tf.Tensor(0.2207109, shape=(), dtype=float32)
# episode 992 Loss tf.Tensor(1.027351, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.80316216, shape=(), dtype=float32)   loss_action tf.Tensor(0.2241889, shape=(), dtype=float32)
# episode 993 Loss tf.Tensor(1.0203134, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.79777026, shape=(), dtype=float32)   loss_action tf.Tensor(0.22254317, shape=(), dtype=float32)
# episode 994 Loss tf.Tensor(1.0206939, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.797875, shape=(), dtype=float32)   loss_action tf.Tensor(0.22281891, shape=(), dtype=float32)
# episode 995 Loss tf.Tensor(1.0214617, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.79855186, shape=(), dtype=float32)   loss_action tf.Tensor(0.2229099, shape=(), dtype=float32)
# episode 996 Loss tf.Tensor(1.0222185, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.79904747, shape=(), dtype=float32)   loss_action tf.Tensor(0.22317095, shape=(), dtype=float32)
# episode 997 Loss tf.Tensor(1.0226462, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.79948175, shape=(), dtype=float32)   loss_action tf.Tensor(0.22316438, shape=(), dtype=float32)
# episode 998 Loss tf.Tensor(1.0169978, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.7948292, shape=(), dtype=float32)   loss_action tf.Tensor(0.2221686, shape=(), dtype=float32)
# episode 999 Loss tf.Tensor(1.0254543, shape=(), dtype=float32)
#          Loss_Voltage tf.Tensor(0.8012379, shape=(), dtype=float32)   loss_action tf.Tensor(0.22421637, shape=(), dtype=float32)

# %%
plt.plot(Loss_record)
plt.xlabel('episoid')
plt.ylabel('Loss')
# plt.title('Non-Discounted Loss without penalty')
# Out:
# Text(0, 0.5, 'Loss')

# %%
modelLinear0.save_weights('/content/drive/MyDrive/Colab Notebooks/250805 data center/data/weights_K_250808.weights.h5')

# %% [markdown]
# # Simulation and Comparisons

# %% [markdown]
# ## With trained controller

# %%
# Plot the trajectory to visulize the performance of control
Trajectory_Linear=[]
linear_coffp = tf.math.minimum(modelLinear0.variables[0], K_bound_p)
linear_coffq = tf.math.minimum(modelLinear0.variables[1], K_bound_q)

Q_init_ratio = 0.6
P_init_ratio = 0.6
delta_t = 1
Q = (Q_ref*np.random.uniform(1-Q_init_ratio ,1+Q_init_ratio ,(dim_action, 1))).T
P = (P_ref*np.random.uniform(1-P_init_ratio ,1+P_init_ratio ,(dim_action, 1))).T

s_concate=P@Matrix_R.T+Q@Matrix_X.T
init_state=s_concate.copy()
s=init_state.copy()
SimulationLength=20
# Record_u_Linear=[]
Record_up_Linear=[]
Record_uq_Linear=[]
Trajectory_Linear.append(s)
Record_Loss_Linear=[]
Loss_Linear=0
print('s',s)
record_v0 = np.diff(record_fault_trajectory[0,0,0,110:])
for i in range(SimulationLength):
    up=np.squeeze(Action_linear(s,linear_coffp))
    uq=np.squeeze(Action_linear(s,linear_coffq))
    next_s= s - uq@Matrix_X - up@Matrix_R + record_v0[i]
    s=next_s.copy()
    Trajectory_Linear.append(s.copy())
    Record_up_Linear.append(up.copy())
    Record_uq_Linear.append(uq.copy())

Trajectory_Linear=np.squeeze(np.asarray(Trajectory_Linear))
fig = plt.figure(figsize=(11,3), dpi=100)
TimeRecord=np.arange(1,SimulationLength+2)
TimeRecord=delta_t*TimeRecord
plt.subplot(1,3,1)
plt.plot(TimeRecord,Trajectory_Linear)
plt.xlabel('time(s)')
plt.ylabel('V (p.u.)')


TimeRecord=np.arange(1,SimulationLength+1)
TimeRecord=delta_t*TimeRecord
plt.subplot(1,3,2)
plt.plot(TimeRecord,Record_up_Linear)
plt.xlabel('time(s)')
plt.ylabel('Action P')

plt.subplot(1,3,3)
plt.plot(TimeRecord,Record_uq_Linear)
plt.xlabel('time(s)')
plt.ylabel('Action Q')
fig.tight_layout()
# Out:
# s [[0.00048409 0.00355356 0.00605264 0.00867938 0.01762234 0.02368456
#   0.02518028 0.02882766 0.03212416 0.03232327 0.03280495 0.03288704
#   0.03333027 0.03361467 0.03388964 0.03375502 0.03378487 0.00049412
#   0.0003181  0.0002765  0.00016821 0.00344125 0.0025216  0.00153792
#   0.01775618 0.01793355 0.01649448 0.01545926 0.0151206  0.01672251
#   0.01712305 0.01708126]]

# %%
plt.plot(TimeRecord,record_v0[:SimulationLength])
plt.xlabel('time(s)')
plt.ylabel('V0 (p.u.)')
# Out:
# Text(0, 0.5, 'V0 (p.u.)')

# %% [markdown]
# ## without control

# %%
# Plot the trajectory to visulize the performance of control
Trajectory_Linear=[]
linear_coffp = tf.math.minimum(modelLinear0.variables[0], K_bound_p)*0
linear_coffq = tf.math.minimum(modelLinear0.variables[1], K_bound_q)*0


init_state=s_concate.copy()
s=init_state.copy()
SimulationLength=20
# Record_u_Linear=[]
Record_up_Linear=[]
Record_uq_Linear=[]
Trajectory_Linear.append(s)
Record_Loss_Linear=[]
Loss_Linear=0
print('s',s)
record_v0 = np.diff(record_fault_trajectory[0,0,0,110:])
for i in range(SimulationLength):
    up=np.squeeze(Action_linear(s,linear_coffp))
    uq=np.squeeze(Action_linear(s,linear_coffq))
    next_s= s - uq@Matrix_X - up@Matrix_R + record_v0[i]
    s=next_s.copy()
    Trajectory_Linear.append(s.copy())
    Record_up_Linear.append(up.copy())
    Record_uq_Linear.append(uq.copy())

Trajectory_Linear=np.squeeze(np.asarray(Trajectory_Linear))
fig = plt.figure(figsize=(11,3), dpi=100)
TimeRecord=np.arange(1,SimulationLength+2)
TimeRecord=delta_t*TimeRecord
plt.subplot(1,3,1)
plt.plot(TimeRecord,Trajectory_Linear)
plt.xlabel('time(s)')
plt.ylabel('V (p.u.)')


TimeRecord=np.arange(1,SimulationLength+1)
TimeRecord=delta_t*TimeRecord
plt.subplot(1,3,2)
plt.plot(TimeRecord,Record_up_Linear)
plt.xlabel('time(s)')
plt.ylabel('Action P')

plt.subplot(1,3,3)
plt.plot(TimeRecord,Record_uq_Linear)
plt.xlabel('time(s)')
plt.ylabel('Action Q')
fig.tight_layout()
# Out:
# s [[0.00048409 0.00355356 0.00605264 0.00867938 0.01762234 0.02368456
#   0.02518028 0.02882766 0.03212416 0.03232327 0.03280495 0.03288704
#   0.03333027 0.03361467 0.03388964 0.03375502 0.03378487 0.00049412
#   0.0003181  0.0002765  0.00016821 0.00344125 0.0025216  0.00153792
#   0.01775618 0.01793355 0.01649448 0.01545926 0.0151206  0.01672251
#   0.01712305 0.01708126]]
